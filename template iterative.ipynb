# %%
# %load_ext autoreload

# %%
# %autoreload 2
import matplotlib.pyplot as plt
from src import gauss_seidel  
from src import gauss_jacobi  
A = [[2, 10], [3, 2]]
b = [16, 11]
x0 = [1, 1]
tol = 1e-1
max_iterations = 100

x_jacobi, tray_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=tol, max_iter=max_iterations)
x_seidel, tray_seidel = gauss_seidel(A=A, b=b, x0=x0, tol=tol, max_iter=max_iterations)

x0_vals_jacobi = [xi[0][0] for xi in tray_jacobi]
x1_vals_jacobi = [xi[1][0] for xi in tray_jacobi]

x0_vals_seidel = [xi[0][0] for xi in tray_seidel]
x1_vals_seidel = [xi[1][0] for xi in tray_seidel]

# Grafica Gauss-Jacobi
plt.figure(figsize=(8, 6))
plt.plot(x0_vals_jacobi, x1_vals_jacobi, linestyle='--', marker='.', label='Iteraciones Gauss-Jacobi')
plt.scatter(tray_jacobi[0][0][0], tray_jacobi[0][1][0], color='blue', marker='s', s=150, label='Punto inicial', edgecolors='black', linewidths=2)
plt.scatter(x_jacobi[0][0], x_jacobi[1][0], color='red', marker='o', s=150, label='Solución final Jacobi', edgecolors='black', linewidths=2)
plt.xlabel('x[0]')
plt.ylabel('x[1]')
plt.title('Método de Gauss-Jacobi')
plt.grid(True)
plt.legend()
plt.show()

# Grafica Gauss-Seidel
plt.figure(figsize=(8, 6))
plt.plot(x0_vals_seidel, x1_vals_seidel, linestyle='--', marker='x', label='Iteraciones Gauss-Seidel')
plt.scatter(tray_seidel[0][0][0], tray_seidel[0][1][0], color='yellow', marker='s', s=150, label='Punto inicial', edgecolors='black', linewidths=2)
plt.scatter(x_seidel[0][0], x_seidel[1][0], color='black', marker='o', s=150, label='Solución final Seidel', edgecolors='black', linewidths=2)
plt.xlabel('x[0]')
plt.ylabel('x[1]')
plt.title('Método de Gauss-Seidel')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [01-25 08:55:48][INFO] i= 0 x: [[1. 1.]]
# [01-25 08:55:48][INFO] i= 1 x: [[3. 4.]]
# [01-25 08:55:48][INFO] i= 2 x: [[-12.   1.]]
# [01-25 08:55:48][INFO] i= 3 x: [[ 3.  23.5]]
# [01-25 08:55:48][INFO] i= 4 x: [[-109.5    1. ]]
# [01-25 08:55:48][INFO] i= 5 x: [[  3.   169.75]]
# [01-25 08:55:48][INFO] i= 6 x: [[-840.75    1.  ]]
# [01-25 08:55:48][INFO] i= 7 x: [[   3.    1266.625]]
# [01-25 08:55:48][INFO] i= 8 x: [[-6.325125e+03  1.000000e+00]]
# [01-25 08:55:48][INFO] i= 9 x: [[3.0000000e+00 9.4931875e+03]]
# [01-25 08:55:48][INFO] i= 10 x: [[-4.74579375e+04  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 11 x: [[3.00000000e+00 7.11924062e+04]]
# [01-25 08:55:48][INFO] i= 12 x: [[-3.55954031e+05  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 13 x: [[3.00000000e+00 5.33936547e+05]]
# [01-25 08:55:48][INFO] i= 14 x: [[-2.66967473e+06  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 15 x: [[3.0000000e+00 4.0045176e+06]]
# [01-25 08:55:48][INFO] i= 16 x: [[-2.002258e+07  1.000000e+00]]
# [01-25 08:55:48][INFO] i= 17 x: [[3.00000000e+00 3.00338755e+07]]
# [01-25 08:55:48][INFO] i= 18 x: [[-1.5016937e+08  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 19 x: [[3.0000000e+00 2.2525406e+08]]
# [01-25 08:55:48][INFO] i= 20 x: [[-1.12627029e+09  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 21 x: [[3.00000000e+00 1.68940544e+09]]
# [01-25 08:55:48][INFO] i= 22 x: [[-8.4470272e+09  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 23 x: [[3.00000000e+00 1.26705408e+10]]
# [01-25 08:55:48][INFO] i= 24 x: [[-6.3352704e+10  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 25 x: [[3.00000000e+00 9.50290561e+10]]
# [01-25 08:55:48][INFO] i= 26 x: [[-4.7514528e+11  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 27 x: [[3.00000000e+00 7.12717921e+11]]
# [01-25 08:55:48][INFO] i= 28 x: [[-3.5635896e+12  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 29 x: [[3.0000000e+00 5.3453844e+12]]
# [01-25 08:55:48][INFO] i= 30 x: [[-2.6726922e+13  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 31 x: [[3.0000000e+00 4.0090383e+13]]
# [01-25 08:55:48][INFO] i= 32 x: [[-2.00451915e+14  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 33 x: [[3.00000000e+00 3.00677873e+14]]
# [01-25 08:55:48][INFO] i= 34 x: [[-1.50338936e+15  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 35 x: [[3.00000000e+00 2.25508405e+15]]
# [01-25 08:55:48][INFO] i= 36 x: [[-1.12754202e+16  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 37 x: [[3.00000000e+00 1.69131303e+16]]
# [01-25 08:55:48][INFO] i= 38 x: [[-8.45656517e+16  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 39 x: [[3.00000000e+00 1.26848478e+17]]
# [01-25 08:55:48][INFO] i= 40 x: [[-6.34242388e+17  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 41 x: [[3.00000000e+00 9.51363582e+17]]
# [01-25 08:55:48][INFO] i= 42 x: [[-4.75681791e+18  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 43 x: [[3.00000000e+00 7.13522686e+18]]
# [01-25 08:55:48][INFO] i= 44 x: [[-3.56761343e+19  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 45 x: [[3.00000000e+00 5.35142015e+19]]
# [01-25 08:55:48][INFO] i= 46 x: [[-2.67571007e+20  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 47 x: [[3.00000000e+00 4.01356511e+20]]
# [01-25 08:55:48][INFO] i= 48 x: [[-2.00678256e+21  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 49 x: [[3.00000000e+00 3.01017383e+21]]
# [01-25 08:55:48][INFO] i= 50 x: [[-1.50508692e+22  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 51 x: [[3.00000000e+00 2.25763037e+22]]
# [01-25 08:55:48][INFO] i= 52 x: [[-1.12881519e+23  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 53 x: [[3.00000000e+00 1.69322278e+23]]
# [01-25 08:55:48][INFO] i= 54 x: [[-8.4661139e+23  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 55 x: [[3.00000000e+00 1.26991709e+24]]
# [01-25 08:55:48][INFO] i= 56 x: [[-6.34958543e+24  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 57 x: [[3.00000000e+00 9.52437814e+24]]
# [01-25 08:55:48][INFO] i= 58 x: [[-4.76218907e+25  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 59 x: [[3.00000000e+00 7.14328361e+25]]
# [01-25 08:55:48][INFO] i= 60 x: [[-3.5716418e+26  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 61 x: [[3.00000000e+00 5.35746271e+26]]
# [01-25 08:55:48][INFO] i= 62 x: [[-2.67873135e+27  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 63 x: [[3.00000000e+00 4.01809703e+27]]
# [01-25 08:55:48][INFO] i= 64 x: [[-2.00904851e+28  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 65 x: [[3.00000000e+00 3.01357277e+28]]
# [01-25 08:55:48][INFO] i= 66 x: [[-1.50678639e+29  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 67 x: [[3.00000000e+00 2.26017958e+29]]
# [01-25 08:55:48][INFO] i= 68 x: [[-1.13008979e+30  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 69 x: [[3.00000000e+00 1.69513468e+30]]
# [01-25 08:55:48][INFO] i= 70 x: [[-8.47567342e+30  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 71 x: [[3.00000000e+00 1.27135101e+31]]
# [01-25 08:55:48][INFO] i= 72 x: [[-6.35675507e+31  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 73 x: [[3.0000000e+00 9.5351326e+31]]
# [01-25 08:55:48][INFO] i= 74 x: [[-4.7675663e+32  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 75 x: [[3.00000000e+00 7.15134945e+32]]
# [01-25 08:55:48][INFO] i= 76 x: [[-3.57567472e+33  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 77 x: [[3.00000000e+00 5.36351209e+33]]
# [01-25 08:55:48][INFO] i= 78 x: [[-2.68175604e+34  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 79 x: [[3.00000000e+00 4.02263406e+34]]
# [01-25 08:55:48][INFO] i= 80 x: [[-2.01131703e+35  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 81 x: [[3.00000000e+00 3.01697555e+35]]
# [01-25 08:55:48][INFO] i= 82 x: [[-1.50848777e+36  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 83 x: [[3.00000000e+00 2.26273166e+36]]
# [01-25 08:55:48][INFO] i= 84 x: [[-1.13136583e+37  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 85 x: [[3.00000000e+00 1.69704875e+37]]
# [01-25 08:55:48][INFO] i= 86 x: [[-8.48524373e+37  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 87 x: [[3.00000000e+00 1.27278656e+38]]
# [01-25 08:55:48][INFO] i= 88 x: [[-6.3639328e+38  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 89 x: [[3.0000000e+00 9.5458992e+38]]
# [01-25 08:55:48][INFO] i= 90 x: [[-4.7729496e+39  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 91 x: [[3.0000000e+00 7.1594244e+39]]
# [01-25 08:55:48][INFO] i= 92 x: [[-3.5797122e+40  1.0000000e+00]]
# [01-25 08:55:48][INFO] i= 93 x: [[3.0000000e+00 5.3695683e+40]]
# [01-25 08:55:48][INFO] i= 94 x: [[-2.68478415e+41  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 95 x: [[3.00000000e+00 4.02717622e+41]]
# [01-25 08:55:48][INFO] i= 96 x: [[-2.01358811e+42  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 97 x: [[3.00000000e+00 3.02038217e+42]]
# [01-25 08:55:48][INFO] i= 98 x: [[-1.51019108e+43  1.00000000e+00]]
# [01-25 08:55:48][INFO] i= 99 x: [[3.00000000e+00 2.26528663e+43]]
# [01-25 08:55:48][INFO] i= 0 x: [[1. 1.]]
# [01-25 08:55:48][INFO] i= 1 x: [[3. 1.]]
